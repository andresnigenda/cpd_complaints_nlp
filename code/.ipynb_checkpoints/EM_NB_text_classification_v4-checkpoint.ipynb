# %% [markdown]
# Update: Increase quantity of labeled and unlabeled documents in training data set.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Import packages and libraries
import numpy as np
import random as rnd
import re
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import KFold, StratifiedKFold, ShuffleSplit
from sklearn import metrics
from sklearn.utils import Bunch

from time import time
from pprint import pprint
from copy import deepcopy
from wordcloud import WordCloud 
from Semi_EM_NB import Semi_EM_MultinomialNB
from os import path
from PIL import Image

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def remove_noise(sentence):
    result = ''
    poster = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    stopword_set = set(stopwords.words('english'))
    wordlist = re.sub(r"\n|(\\(.*?){)|}|[!$%^&*#()_+|~\-={}\[\]:\";'<>?,.\/\\]|[0-9]|[@]", ' ', sentence) # remove punctuation
    wordlist = re.sub('\s+', ' ', wordlist) # remove extra space
    wordlist_normal = [poster.stem(word.lower()) for word in wordlist.split()] # restore word to its original form (stemming)
    wordlist_normal = [lemmatizer.lemmatize(word, pos='v') for word in wordlist_normal] # restore word to its root form (lemmatization)
    wordlist_clean = [word for word in wordlist_normal if word not in stopword_set] # remove stopwords
    result = ' '.join(wordlist_clean)
    return result

# %%
def cross_validation(clf, data_X, data_y, unlabeled=None, n_folds=5):
    print('=' * 80)
    print("Validation: ")
    print(clf)
    kf = StratifiedKFold(n_splits=n_folds)
    start_time = time()
    train_accuracies= list() # training accuracy
    fold_count = 1
    original_clf = deepcopy(clf)
    for train_ids, valid_ids in kf.split(data_X, data_y):
        cv_clf = deepcopy(original_clf)
        print("Fold # %d" % fold_count)
        fold_count += 1
        train_X, train_y, valid_X, valid_y = data_X[train_ids], data_y[train_ids], data_X[valid_ids], data_y[valid_ids]
        if unlabeled==None:
            cv_clf.fit(train_X, train_y)
        else:
            cv_clf.fit(train_X, train_y, unlabeled)
        pred = cv_clf.predict(valid_X)
        train_accuracies.append(metrics.accuracy_score(valid_y, pred))
    train_time = time() - start_time
    print("Validation time: %0.3f seconds" % train_time)
    print("Average training accuracy: %0.3f" % np.mean(np.array(train_accuracies)))
    return train_accuracies, train_time

# %%
def show_topK(classifier, vectorizer, categories, K=10):
    feature_names = np.asarray(vectorizer.get_feature_names())
    nrows, ncols = 5, 4
    fig, axes = plt.subplots(figsize=(50, 40), nrows=nrows, ncols=ncols)
    #d = path.dirname(__file__)
    circle_mask = np.array(Image.open(path.join('./', "circle.png")))
    for i, category in enumerate(categories):
        topK = np.argsort(classifier.coef_[i])[-K:]
        text = " ".join(feature_names[topK])
        print("%s: %s" % (category, text))
        wordcloud = WordCloud(background_color="white", mask=circle_mask).generate(text)
        axes[i//ncols, i%ncols].imshow(wordcloud, cmap=plt.cm.cool_r, interpolation='bilinear')
        axes[i//ncols, i%ncols].axis("off")
        axes[i//ncols, i%ncols].set_title(category, fontweight="bold", size=24)
    plt.show()

# %%
import pandas as pd
text = pd.read_csv("training_with_text.csv")
text_filled = text.loc[pd.notna(text.text_content)]
def clean_text(row):
  no_n = row['text_content'].replace('\n', ' ')
  no_special = re.sub("[^a-zA-Z0-9]+", ' ', no_n)
  return re.sub('\d', ' ', no_special)
text_filled['text_content'] = text_filled.apply(lambda x: clean_text(x), axis=1)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
  target_names_lst = [u'nudity_penetration',
  u'sexual_relations_with_a_minor_', u'sexual_harassment_sexual_remarks',
  u'domestic_violence_police_committing_',
  u'sexual_humiliation_sexual_extortion_prostitution_sex_work',
  u'tasers_baton_aggressive_physical_touch_gun', u'trespass_robbery',
  u'biometric_surveillance_fitting_a_description_gang_related_',
  u'racial_slurs_xenophobic_remarks_',
  u'undocumented_status_asking_for_someone_s_status_calling_ice_',
  u'planting_drug_guns', u'neglect_of_duty_failure_to_serve',
  u'refusing_to_provide_medical_assistance', u'workplace_harassment',
  u'_irrational_aggressive_unstable_', u'suicide_in_jail_improper_care_',
  u'dcfs_threats', u'pregnant_women', u'school',
  u'searching_patting_down_arresting_minors']

# %%
for category in target_names_lst:
  if text_filled[category].sum() < 2:
    print(category)
    text_filled.drop(columns=category, inplace=True)
    target_names_lst.remove(category)
text_filled.head()
# Out:
# sexual_relations_with_a_minor_
# undocumented_status_asking_for_someone_s_status_calling_ice_
# workplace_harassment
# suicide_in_jail_improper_care_
# pregnant_women
#    _allegation_id  ...                         source_type
# 0          297735  ...                       DOCUMENTCLOUD
# 1          300059  ...                       DOCUMENTCLOUD
# 2         1089005  ...  SUMMARY_REPORTS_COPA_DOCUMENTCLOUD
# 3          299023  ...                       DOCUMENTCLOUD
# 4          313007  ...                       DOCUMENTCLOUD
#
# [5 rows x 33 columns]

# %%
label_index = {label: index for (index, label) in enumerate(target_names_lst)}

# %%
def build_target(row):
  marked_labels = []
  for label in row[target_names_lst].index:
    if row[label] == 1:
      marked_labels.append(label)
  if len(marked_labels) >= 1:
    chosen = rnd.choice(marked_labels)
    return int(label_index[chosen])
  else:
    return None

text_filled['target_vals'] = text_filled.apply(build_target, axis=1)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
text_filled = text_filled.loc[pd.notna(text_filled.target_vals)]

# %%
data_Xy = Bunch(data = list(text_filled.text_content), 
                  target = np.array(text_filled.target_vals),
                  target_names = target_names_lst)

# %%
# Load data set with class labels and split into train and test set
test_size_ratio = 0.2
# data_Xy = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'), shuffle=True)
category_names = data_Xy.target_names # text names of all categories
train_X, test_X, train_y, test_y = train_test_split(data_Xy.data, data_Xy.target, test_size=test_size_ratio, stratify=data_Xy.target, random_state=42)
print("Training set size: %8d\tTest set size: %8d" % (len(train_X), len(test_X)))
# Out:
# Training set size:      180	Test set size:       45

# %%
# Load data set with class labels and split into train and test set
test_size_ratio = 0.2
data_Xy = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'), shuffle=True)
category_names = data_Xy.target_names # text names of all categories
train_X, test_X, train_y, test_y = train_test_split(data_Xy.data, data_Xy.target, test_size=test_size_ratio, stratify=data_Xy.target, random_state=42)
print("Training set size: %8d\tTest set size: %8d" % (len(train_X), len(test_X)))
# Out:
# Training set size:    15076	Test set size:     3770

# %%
# preprocess train and test text data
train_X_clean = map(remove_noise, train_X)
test_X_clean = map(remove_noise, test_X)

# %%
# Convert all text data into tf-idf vectors 
vectorizer = TfidfVectorizer(stop_words='english', min_df=5, max_df=0.95)
# vectorizer = TfidfVectorizer()
train_vec = vectorizer.fit_transform(train_X_clean)
test_vec = vectorizer.transform(test_X_clean)
print train_vec.shape, test_vec.shape
# Out:
# (180, 4167) (45, 4167)

# %%
# Divide train data set into labeled and unlabeled data sets
split_ratio = 0.3 
X_l, X_u, y_l, y_u = train_test_split(train_vec, train_y, train_size=split_ratio, stratify=train_y)
print X_l.shape, X_u.shape
# Out:
# (54, 4167) (126, 4167)

# %%
# Cross validation for Naive Bayes classifier 
# using labeled data set only
nb_clf = MultinomialNB(alpha=1e-2)
cross_validation(nb_clf, X_l, y_l)
# Out:
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.035 seconds
# Average training accuracy: 0.558
# /usr/local/lib/python2.7/dist-packages/sklearn/model_selection/_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# ([0.35294117647058826, 0.6363636363636364, 0.8, 0.5, 0.5],
#  0.034880876541137695)

# %%
# Cross validation for semisupervised EM Naive Bayes classifier 
# using both labeled and unlabeled data set
em_nb_clf = Semi_EM_MultinomialNB(alpha=1e-2, tol=100, print_log_lkh=False) # semi supervised EM based Naive Bayes classifier
cross_validation(em_nb_clf, X_l, y_l, X_u)
# Out:
# ================================================================================
# Validation:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# Fold # 1
# Fold # 2
# Fold # 3
# Fold # 4
# Fold # 5
# Validation time: 0.329 seconds
# Average training accuracy: 0.538
# ([0.23529411764705882, 0.7272727272727273, 0.6, 0.5, 0.625],
#  0.32898807525634766)

# %%
# Evaluate original NB classifier using test data set
nb_clf = MultinomialNB(alpha=1e-2).fit(X_l, y_l)
pred = nb_clf.predict(test_vec)
#print(metrics.classification_report(test_y, pred, target_names=category_names))
# pprint(metrics.confusion_matrix(test_Xy.target, pred))
print(metrics.accuracy_score(test_y, pred))
# Out:
# 0.5111111111111111

# %%
# Evaluate semi-supervised EM NB classifier using test data set
em_nb_clf = Semi_EM_MultinomialNB(alpha=1e-2, tol=100, print_log_lkh=False).fit(X_l, y_l, X_u)
pred = em_nb_clf.predict(test_vec)
#print(metrics.classification_report(test_y, pred, target_names=category_names))
# pprint(metrics.confusion_matrix(test_Xy.target, pred))
print(metrics.accuracy_score(test_y, pred))
# Out:
# 0.4444444444444444

# %%
show_topK(nb_clf, vectorizer, category_names, K=30) # keywords for each class by original NB classifier
# Out:
# nudity_penetration: justif recal north drug district driver wear harass stop cell ave custodi narcot ask hi releas surveil gun conduct perform arrest exchang grand februari vehicl enforc copa search strip subject
# sexual_harassment_sexual_remarks: form incid march raymond standard profession non code car win mar chicago question street counsel hear examin interrog advis anthoni piwnicki pdt assign time absenc cer unit martin date ms
# domestic_violence_police_committing_: accid girlfriend audio leav decemb pop stop block novemb log request hi account messag media say send resid home longer harass friend contact civilian tell relationship want mother copa subject
# sexual_humiliation_sexual_extortion_prostitution_sex_work: ani complaint hand face att assign telephon duti mm page smith vehicl injur attach complain hour strike piwnicki incid recommend unit arrest time profession subject standard watt date hi cer
# tasers_baton_aggressive_physical_touch_gun: mm rev secur list request inform herebi signatur cpd duti regist charg statement chicago sgt complaint right assign form recommend hear time counsel interrog examin advis complain unit date attach
# trespass_robbery: statement ani occur tabl reason defend month cap fact defens matter page par time order recollect becaus moreov custom hi murphi plaintiff king cour judg testifi offcer testimoni delay board
# biometric_surveillance_fitting_a_description_gang_related_: bear road spray say right ryan unit disobey ani refer decemb statement order counsel answer near write carey interrog examin advis question complain time date board hear cer sullivan scott
# racial_slurs_xenophobic_remarks_: cr dna complaint list ste interview subject incid drug time seq hi charg recommend sergeant address robert unit johnson watt stegmil plant arrest complain cer cunningham date attach christ savicka
# planting_drug_guns: request crime injur wayn hi tate area contact john respond crimin interview batteri properti mr time date attorney unit geisbush damag cannon victim offend attach complain landlord cer sgt detect
# neglect_of_duty_failure_to_serve: examin question interrog time cpo anael counsel advis reason pleas head ani moham march rio complain unit request unavail form brown william wall date page kenneth young mr exhibit carter
# refusing_to_provide_medical_assistance: hand bitch subject advis ani right chief cunt statement unit nigger bottl interview shorter south raymond troy time patient michael date smith ce profession standard august goldston piwnicki ms cer
# IndexErrorTraceback (most recent call last)
# <ipython-input-184-2f7bf91419eb> in <module>()
# ----> 1 show_topK(nb_clf, vectorizer, category_names, K=30) # keywords for each class by original NB classifier
#
# <ipython-input-183-d5629c196298> in show_topK(classifier, vectorizer, categories, K)
#       6     circle_mask = np.array(Image.open(path.join('./', "circle.png")))
#       7     for i, category in enumerate(categories):
# ----> 8         topK = np.argsort(classifier.coef_[i])[-K:]
#       9         text = " ".join(feature_names[topK])
#      10         print("%s: %s" % (category, text))
#
# IndexError: index 11 is out of bounds for axis 0 with size 11

# %%
show_topK(em_nb_clf, vectorizer, category_names, K=30) # keywords for each class by semisupervised EM NB classifier
# Out:
# nudity_penetration: justif recal north drug district driver wear harass stop cell ave custodi narcot ask hi releas surveil gun conduct perform arrest exchang grand februari vehicl enforc copa search strip subject
# sexual_harassment_sexual_remarks: form incid march raymond standard profession non code car win mar chicago question street counsel hear examin interrog advis anthoni piwnicki pdt assign time absenc cer unit martin date ms
# domestic_violence_police_committing_: accid girlfriend audio leav decemb pop stop block novemb log request hi account messag media say send resid home longer harass friend contact civilian tell relationship want mother copa subject
# sexual_humiliation_sexual_extortion_prostitution_sex_work: mr telephon list treaci page po disciplinari att vehicl assign complaint hour support piwnicki duti injur watt subject incid arrest profession standard complain time attach unit recommend date hi cer
# tasers_baton_aggressive_physical_touch_gun: list proceed duti cpd cr signatur arrest charg chicago statement secur assign complaint cer request recommend hear right form mm sgt interrog examin advis time counsel complain unit date attach
# trespass_robbery: requir kitchen time charg recollect claim men gang custom moreov cour app order tabl king video decis restaur becaus judg say offcer hi walsh delay testifi plaintiff testimoni murphi board
# biometric_surveillance_fitting_a_description_gang_related_: decemb pb chief martinez north time avenu date herebi write duti count near april oral rule ani daniel illinoi citi charg scott guilti chicago decis sullivan respond award hear board
# racial_slurs_xenophobic_remarks_: charg address assign il list code injur ot er time race duti ic tl recommend ii sex ti stegmil va hi unit incid complain attach arrest utrera date christ savicka
# planting_drug_guns: request crime injur wayn hi tate area contact john respond crimin interview batteri properti mr time date attorney unit geisbush damag cannon victim offend attach complain landlord cer sgt detect
# neglect_of_duty_failure_to_serve: examin question interrog time cpo anael counsel advis reason pleas head ani moham march rio complain unit request unavail form brown william wall date page kenneth young mr exhibit carter
# refusing_to_provide_medical_assistance: hand bitch subject advis ani right chief cunt statement unit nigger bottl interview shorter south raymond troy time patient michael date smith ce profession standard august goldston piwnicki ms cer
# IndexErrorTraceback (most recent call last)
# <ipython-input-185-934e18ede648> in <module>()
# ----> 1 show_topK(em_nb_clf, vectorizer, category_names, K=30) # keywords for each class by semisupervised EM NB classifier
#
# <ipython-input-183-d5629c196298> in show_topK(classifier, vectorizer, categories, K)
#       6     circle_mask = np.array(Image.open(path.join('./', "circle.png")))
#       7     for i, category in enumerate(categories):
# ----> 8         topK = np.argsort(classifier.coef_[i])[-K:]
#       9         text = " ".join(feature_names[topK])
#      10         print("%s: %s" % (category, text))
#
# IndexError: index 11 is out of bounds for axis 0 with size 11
